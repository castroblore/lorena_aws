# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
nombre = "Interestelar"
anio = 2014
Visto = True

print(nombre + " " + str(anio) + " " + str(Visto))
# Out:
# Interestelar 2014 True

# %%
peliculas = [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

anios = [
    1994, 2008, 2010, 1994, 1999,
    2014, 2019, 2000, 1997, 2001
]

taquillera = [
    True, False, True, False, True,
    False, True, False, True, False
]

for nombre, anio, exito in zip(peliculas, anios, taquillera):
    print(f"{nombre} ({anio}) - Taquillera: {exito}")
# Out:
# The Shawshank Redemption (1994) - Taquillera: True
# The Dark Knight (2008) - Taquillera: False
# Inception (2010) - Taquillera: True
# Pulp Fiction (1994) - Taquillera: False
# The Matrix (1999) - Taquillera: True
# Interstellar (2014) - Taquillera: False
# Parasite (2019) - Taquillera: True
# Gladiator (2000) - Taquillera: False
# Titanic (1997) - Taquillera: True
# The Lord of the Rings: The Fellowship of the Ring (2001) - Taquillera: False

# %%
nombre = "Lorena"
print("Hola {nombre}")
# Out:
# Hola {nombre}

# %%
nombre = "Lorena"
print(f"Hola {nombre}")
# Out:
# Hola Lorena
